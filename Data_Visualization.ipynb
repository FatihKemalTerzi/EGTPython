# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # Categorical Variable Vizualization

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0         0       3    male  22.0      1      0   7.2500        S  Third    man        True  NaN  Southampton    no  False
# 1         1       1  female  38.0      1      0  71.2833        C  First  woman       False    C    Cherbourg   yes  False
# 2         1       3  female  26.0      0      0   7.9250        S  Third  woman       False  NaN  Southampton   yes   True
# 3         1       1  female  35.0      1      0  53.1000        S  First  woman       False    C  Southampton   yes  False
# 4         0       3    male  35.0      0      0   8.0500        S  Third    man        True  NaN  Southampton    no   True

# %%
df['sex'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# # Numerical Variable Visualization

# %%
plt.hist(df["age"])
plt.show()

# %%
plt.boxplot(df["fare"])
plt.show()

# %%
x = np.array([1,8])
y = np.array([0,150])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'o')
plt.show()

# %%
x = np.array([2,5,6,8,10])
y = np.array([1,3,5,7,9])

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# # marker

# %%
y = np.array([13,28,11,100])

# %%
plt.plot(y,marker='*')
plt.show()

# %% [markdown]
# # line

# %%
y = np.array([13,28,11,100])

# %%
plt.plot(y)
plt.show()

# %%
plt.plot(y, linestyle='dashed')
plt.show()

# %%
plt.plot(y, linestyle='dashed', color="r")
plt.show()

# %% [markdown]
# # Multiple Lines

# %%
x = np.array([23,18,31,10])
y = np.array([13,28,11,100])
plt.plot(x)
plt.plot(y)
plt.show()

# %% [markdown]
# # Labels

# %%
x = np.array([80,85,90,95,100])
y = np.array([240,250,260,270,300])
plt.plot(x,y)
plt.title("Bu ana başlık")
plt.show()

# %%
#naming of x axis
plt.plot(x,y)
plt.title("Bu ana başlık")
plt.xlabel("X ekseni isimlendirmesi")
plt.show()

# %%
#naming of y axis
plt.plot(x,y)
plt.title("Bu ana başlık")
plt.ylabel("Y ekseni isimlendirmesi")
plt.show()

# %%
plt.grid()

# %%
plt.plot(x,y)
plt.title("Bu ana başlık")
plt.ylabel("Y ekseni isimlendirmesi")
plt.grid()
plt.show()

# %%
x = np.array([80,85,90,95,100,105,115,125,140,160,200])
y = np.array([240,250,260,270,300,330,360,390,440,450,500])
plt.subplot(1,3,1)
plt.title("1")
plt.plot(x,y)
plt.show()
#plt.subplot(1,3,1) ile 1 e 3 lük bir grafik ouşturucağımı söylüyorum ve 1. sini verdiğimi söylüyorum

# %%
x = np.array([80,85,90,95,100,105,115,125,140,160,200])
y = np.array([240,250,260,270,300,330,360,390,440,450,500])
plt.subplot(1,3,2)
plt.title("2")
plt.plot(x,y)
plt.show()

# %%
x = np.array([80,85,90,95,100,105,115,125,140,160,200])
y = np.array([240,250,260,270,300,330,360,390,440,450,500])
plt.subplot(1,3,1)
plt.title("1")
plt.plot(x,y)
x = np.array([80,85,90,95,100,105,115,125,140,160,200])
y = np.array([240,250,260,270,300,330,360,390,440,450,500])
plt.subplot(1,3,2)
plt.title("2")
plt.plot(x,y)
plt.show()

# %%
x = np.array([80,85,90,95,100,105,115,125,140,160,200])
y = np.array([240,250,260,270,300,330,360,390,440,450,500])
plt.subplot(1,3,1)
plt.title("1")
plt.plot(x,y)
x = np.array([80,85,90,95,100,105,115,125,140,160,200])
y = np.array([240,250,260,270,300,330,360,390,440,450,500])
plt.subplot(1,3,2)
plt.title("2")
plt.plot(x,y)
x = np.array([80,85,90,95,100,105,115,125,140,160,200])
y = np.array([240,250,260,270,300,330,360,390,440,450,500])
plt.subplot(1,3,3)
plt.title("3")
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Seaborn

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.countplot(x=df["sex"],data=df)
plt.show()

# %%
sns.boxplot(x=df["total_bill"])
plt.show()

# %%
df["total_bill"].hist()
plt.show()
