# %%
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("titanic")

# %%
df["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df["pclass"].nunique()
# Out:
# 3

# %%
df[["pclass","parch"]].nunique()
# Out:
# pclass    3
# parch     7
# dtype: int64

# %%
df["embarked"].dtype
str(df["embarked"].dtype)
df["embarked"] = df["embarked"].astype("category")
str(df["embarked"].dtype)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    category
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(3), float64(2), int64(4), object(4)
# memory usage: 74.7+ KB

# %%
df[df["embarked"]=="C"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# 26          0       3    male   NaN      0      0   7.2250        C   Third
# 30          0       1    male  40.0      0      0  27.7208        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
df[(df["embarked"]!="S")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
df[(df["age"]<30) & (df["sex"] =="female")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[(df["fare"]>500) | (df["age"]>70)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 96          0       1    male  71.0      0      0   34.6542        C  First
# 116         0       3    male  70.5      0      0    7.7500        Q  Third
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 493         0       1    male  71.0      0      0   49.5042        C  First
# 630         1       1    male  80.0      0      0   30.0000        S  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 851         0       3    male  74.0      0      0    7.7750        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# 258  woman       False  NaN    Cherbourg   yes   True
# 493    man        True  NaN    Cherbourg    no   True
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.drop("who",axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df["deck"].fillna(df["deck"].mode()[0],inplace = True)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck             0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["age"].fillna(df["age"].median(),inplace = True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df.groupby(["pclass","sex"]).agg({"survived":["sum","count","mean"]})
# Out:
#               survived
#                    sum count      mean
# pclass sex
# 1      female       91    94  0.968085
#        male         45   122  0.368852
# 2      female       70    76  0.921053
#        male         17   108  0.157407
# 3      female       72   144  0.500000
#        male         47   347  0.135447

# %%
df["age_flag"] = df["age"].apply(lambda x : 1 if x < 30 else 0)

# %%
df["age_flag"]
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 886    1
# 887    1
# 888    1
# 889    1
# 890    0
# Name: age_flag, Length: 891, dtype: int64

# %%
df_tips = sns.load_dataset("tips")

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df_tips.groupby(["time"]).agg({"total_bill":["min","max","mean"]})
# Out:
#        total_bill
#               min    max       mean
# time
# Lunch        7.51  43.11  17.168676
# Dinner       3.07  50.81  20.797159

# %%
df_tips.groupby(["day","time"]).agg({"total_bill":["min","max","mean"]})
# Out:
#             total_bill
#                    min    max       mean
# day  time
# Thur Lunch        7.51  43.11  17.664754
#      Dinner      18.78  18.78  18.780000
# Fri  Lunch        8.58  16.27  12.845714
#      Dinner       5.75  40.17  19.663333
# Sat  Lunch         NaN    NaN        NaN
#      Dinner       3.07  50.81  20.441379
# Sun  Lunch         NaN    NaN        NaN
#      Dinner       7.25  48.17  21.410000

# %%
df_tips[(df_tips["time"]=="Lunch")&(df_tips["sex"]=="Female")].groupby(["day"]).agg({"total_bill":["sum","min","max","mean"],"tip":["min","max","mean"]})
# Out:
#      total_bill                           tip
#             sum    min    max      mean   min   max      mean
# day
# Thur     516.11   8.35  43.11  16.64871  1.25  5.17  2.561935
# Fri       55.76  10.09  16.27  13.94000  2.00  3.48  2.745000
# Sat        0.00    NaN    NaN       NaN   NaN   NaN       NaN
# Sun        0.00    NaN    NaN       NaN   NaN   NaN       NaN

# %%
df_tips.loc[(df_tips["size"] < 3) & (df_tips["total_bill"] >10), "total_bill"].mean()
# Out:
# 17.18496503496505

# %%
df_tips["total_bill_tip_sum"] = df_tips["total_bill"] + df_tips["tip"]

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_bill_tip_sum
# 0       16.99  1.01  Female     No  Sun  Dinner     2               18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3               12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3               24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2               26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4               28.20

# %%
df_tips.sort_values(by=["total_bill_tip_sum"], ascending=True).head(30)
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_tip_sum
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1                4.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2                6.75
# 111        7.25  1.00  Female     No   Sat  Dinner     1                8.25
# 195        7.56  1.44    Male     No  Thur   Lunch     2                9.00
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2                9.18
# 149        7.51  2.00    Male     No  Thur   Lunch     2                9.51
# 135        8.51  1.25  Female     No  Thur   Lunch     2                9.76
# 145        8.35  1.50  Female     No  Thur   Lunch     2                9.85
# 126        8.52  1.48    Male     No  Thur   Lunch     2               10.00
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1               10.50
# 6          8.77  2.00    Male     No   Sun  Dinner     2               10.77
# ...

# %%
new_df = df_tips.sort_values(by=["total_bill_tip_sum"], ascending=True).head(30)

# %%
new_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_tip_sum
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1                4.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2                6.75
# 111        7.25  1.00  Female     No   Sat  Dinner     1                8.25
# 195        7.56  1.44    Male     No  Thur   Lunch     2                9.00
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2                9.18
# 149        7.51  2.00    Male     No  Thur   Lunch     2                9.51
# 135        8.51  1.25  Female     No  Thur   Lunch     2                9.76
# 145        8.35  1.50  Female     No  Thur   Lunch     2                9.85
# 126        8.52  1.48    Male     No  Thur   Lunch     2               10.00
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1               10.50
# 6          8.77  2.00    Male     No   Sun  Dinner     2               10.77
# ...
